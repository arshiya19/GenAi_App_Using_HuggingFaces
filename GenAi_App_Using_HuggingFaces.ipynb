# %%
## Libraries Reuqired

# !pip install langchain-huggingface

## for api calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain

## for huggingface api
# !huggingface-cli
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 5.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...

# %%
#enviroment secret keys
#below line will take the tokens from the secrets section
from google.colab import userdata
secret_key = userdata.get('HF_TOKEN')
print(secret_key)
# Out:
# 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

# %% [markdown]
# # HuggingFaceEndpoint

# %% [markdown]
# Interacting with model with the help of huggingface endpoint

# %% [markdown]
# This model is mainly used for text generation

# %%
from langchain_huggingface import HuggingFaceEndpoint
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = secret_key

repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id=repo_id,temperature=0.5,model_kwargs={"max_length":200,"token":secret_key})
print(llm)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# HuggingFaceEndpoint
# Params: {'endpoint_url': None, 'task': None, 'model_kwargs': {'max_length': 200, 'token': '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'}}

# %%
llm.invoke('What is Machine Learning?')
# Out:
# '\n\nMachine Learning is a subset of artificial intelligence that provides systems the ability to automatically learn and improve from experience without being explicitly programmed. Machine Learning focuses on the development of computer programs that can access data and use it to learn for themselves. The process of learning begins with observations or data, such as examples, direct experience, or instruction, in order to look for patterns in data and make better decisions in the future based on the examples that we provide. The primary aim is to allow the computers to learn automatically without human intervention or assistance and adjust actions accordingly.\n\nTypes of Machine Learning:\n\n1. Supervised Learning: In supervised learning, the model is provided with a labeled dataset. The model learns from the data and tries to predict the output for the new, unseen data. The dataset consists of input variables and their corresponding output variables. The goal is to learn a mappin
# ...

# %%
llm.invoke('Who is ShahRukh Khan?')
# Out:
# '\n\nShah Rukh Khan, also known as SRK, is an Indian actor, producer, and television personality who works in Hindi films. He is often referred to as the "Baadshah of Bollywood" and "King Khan" due to his popularity and influence in the Indian film industry.\n\nBorn on November 2, 1965, in New Delhi, Shah Rukh Khan moved to Mumbai (then Bombay) to pursue a career in acting. He made his debut in 1992 with the film Deewana and gained recognition with films like Dilwale Dulhania Le Jayenge (1995), Dil To Pagal Hai (1997), Kuch Kuch Hota Hai (1998), and Mohabbatein (2000).\n\nKnown for his romantic roles, Khan has also ventured into various genres, including action, comedy, and drama. Some of his notable films include Don (2006), Chak De! India (2007), Rab Ne Bana Di Jodi (2008), My Name Is Khan (2010), and Chennai Express (2013).\n\nIn addition to acting, Shah Rukh Khan has also produced several films under his production company, Red Chillies Entertainment. He has won numerous awards, 
# ...

# %%
repo_id = "mistralai/Mistral-7B-Instruct-v0.3"
llm = HuggingFaceEndpoint(repo_id=repo_id,temperature=0.5,model_kwargs={"max_length":200,"token":secret_key})
print(llm)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# HuggingFaceEndpoint
# Params: {'endpoint_url': None, 'task': None, 'model_kwargs': {'max_length': 200, 'token': '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'}}

# %%
from tempfile import template
from langchain import PromptTemplate
question = "What are popular movies of SRK"

template = """Question: {question}
Answer:"""
prompt = PromptTemplate(template=template, input_variables=["question"])

final_chain = prompt | llm
print(final_chain.invoke(question))
# Out:
#  Shah Rukh Khan, often known as King Khan, is one of the most popular actors in Bollywood. Some of his most popular movies include:
#
# 1. Dilwale Dulhania Le Jayenge (1995)
# 2. Kuch Kuch Hota Hai (1998)
# 3. Mohabbatein (2000)
# 4. Kabhi Khushi Kabhie Gham (2001)
# 5. Veer-Zaara (2004)
# 6. Swades (2004)
# 7. Chak De! India (2007)
# 8. Rab Ne Bana Di Jodi (2008)
# 9. My Name Is Khan (2010)
# 10. Chennai Express (2013)
# 11. Happy New Year (2014)
# 12. Dilwale (2015)
# 13. Dear Zindagi (2016)
# 14. Zero (2018)
#
# These films have been well-received by audiences and critics alike, and many of them have broken box office records.

# %% [markdown]
# ## Hugging Face Pipeline

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM,pipeline

# %%
model_id = "gpt2"

# %%
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
## pipelines

pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=200)
hf = HuggingFacePipeline(pipeline = pipe)
hf.invoke("What is Machine Learning?")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...
